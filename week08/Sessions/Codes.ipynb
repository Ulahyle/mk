# %%
# NetWork

# Server

# Client

# Router

# Switch

# IP

# MAC Adress

# LAN

# WAN

# PACKET

# PACKET lost

# Ping

# traceroute

# iconfig

# netstat

# nslookup

# DNS

# Http/Https

# http response status codes

# RESTful api

# CRUD

# Load balancing

# %%
# LINUX

# cd/

# ls #list of files in certain directory

# ls -a #list of files in certain directory includes hidden files

# ls -l # ll #all detailes of each file 

# home #like username in windows

# absolute adress

# relative address

# pwd #shows us the absolute adress

# cd #move around directories

# ../

# asm

# cd ~ #back to home

# cd ~/Desktop #back to home go to desktop

# powerlevel10k

# mkdir #makes folder in certain directory

# mkdir -p new_folder/in_folder #makes new_folder and makes in_folder in that

# touch #makes file in certain directory

# cp file_name directory_name #copy file

# cp -r directory-name-1 directory-name-2 #copy folder

# mv file_name_1 file_name_2 #rename

# mv file_name new_folder_name #move

# mv file_name ../certain_folder #move file one level back

# rm #delete file

# rm -r #delete folder

# rmdir #delete directory

# man #manual

# man rm #explanations for rm and its args

# -q #get out

# -q --quiet #actual word argomans get --

# cat #prints what's in the file

# less #like cat navigates in what is in file

# more #like cat navigates in what is in file

# head #first 10 line of what is in the file

# tail #last 10 line of what is in the file

# ls -l #1st three letter user's accessibility level 2nd three letters underGroup's accessibility 3rd three letters other's accessibility

# chmod _ _ _ file_name #change accessibility

# chown user:group file_name #change ownership
